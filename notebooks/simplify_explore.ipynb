# %%
import os, glob, pickle

import numpy as np
import pandas as pd
import networkx as nx

# %%
csv_path = os.path.join('~','global-fossil-fuel-supply-chain','ffsc_kedro_pipeline','results','output')

# %%
csv_files = glob.glob('/home/ubuntu/global-fossil-fuel-supply-chain/results/output/*')

# %%
csv_files
# Out:
# ['/home/ubuntu/global-fossil-fuel-supply-chain/results/output/power_station_nodes_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/oil_field_edge_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/shipping_node_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/coal_mine_railway_edge_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/coal_mines_nodes_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/cities_nodes_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/pipeline_edge_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/refinery_pipeline_edge_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/processing_plant_nodes_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/lng_nodes_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/cities_railways_edge_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/port_node_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/well_pad_pipeline_edge_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/cities_pipelines_edge_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/shipping_edge_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/oil_field_nodes_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/power_station_railway_edge_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/processing_plant_pipeline_edge_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/cities_ports_edge_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/port_pipeline_edge_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/refinery_nodes_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/pipeline_node_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/railway_nodes_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/well_pad_nodes_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/railway_edge_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/port_ship_edge_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/lng_shipping_route_edge_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/lng_pipeline_edge_dataframe.csv',
#  '/home/ubuntu/global-fossil-fuel-supply-chain/results/output/power_station_pipeline_edge_dataframe.csv']

# %%
dfs = {}

# %%
for f in csv_files:
    kk = f.split('/')[-1].split('.')[0]
    print (kk)
    dfs[kk] = pd.read_csv(f)
# Out:
# power_station_nodes_dataframe
# oil_field_edge_dataframe
# shipping_node_dataframe
# coal_mine_railway_edge_dataframe
# coal_mines_nodes_dataframe
# cities_nodes_dataframe
# pipeline_edge_dataframe
# refinery_pipeline_edge_dataframe
# processing_plant_nodes_dataframe
# lng_nodes_dataframe
# cities_railways_edge_dataframe
# port_node_dataframe
# well_pad_pipeline_edge_dataframe
# cities_pipelines_edge_dataframe
# shipping_edge_dataframe
# oil_field_nodes_dataframe
# power_station_railway_edge_dataframe
# processing_plant_pipeline_edge_dataframe
# cities_ports_edge_dataframe
# port_pipeline_edge_dataframe
# refinery_nodes_dataframe
# pipeline_node_dataframe
# railway_nodes_dataframe
# well_pad_nodes_dataframe
# railway_edge_dataframe
# port_ship_edge_dataframe
# lng_shipping_route_edge_dataframe
# lng_pipeline_edge_dataframe
# power_station_pipeline_edge_dataframe

# %%
for kk in sorted(list(dfs.keys())):
    print (kk)

# %%
dfs['pipeline_node_dataframe'].set_index('PipeNodeID:ID(PipelineNode)', inplace=True)

# %%
dfs['railway_edge_dataframe'].head(20)
# Out:
#                     StartNodeId:START_ID(RailwayNode)  \
# 0     railway_node_81.1458067772870851.17616448058104
# 1   railway_node_-40.779270833828264-5.53331712476...
# 2   railway_node_-40.83752818595551-5.514524011734167
# 3    railway_node_98.2259611453085614.097502175406158
# 4    railway_node_98.2259611456299814.008849119211256
# 5    railway_node_98.2791529794628213.813812394933798
# 6    railway_node_98.2835856324512613.769485866131399
# 7     railway_node_98.3545080778245513.75175525485712
# 8    railway_node_98.3899692996095213.645371587462634
# 9     railway_node_98.4431611337160613.56115118434701
# 10   railway_node_98.4919203146047313.468065475011727
# 11    railway_node_98.545112148347213.366114459936707
# 12   railway_node_98.6071692878183213.295192015078314
# 13   railway_node_98.6514958160888713.224269569285008
# 14   railway_node_98.6426305103986313.073559374471198
# 15   railway_node_98.6736590797435712.971608359335743
# 16   railway_node_98.6647937748742812.905118566507909
# 17   railway_node_98.6869570393551212.838628774152246
# 18   railway_node_98.7179856082336512.798734898914958
# 19    railway_node_98.7357162194619312.68791857922513
#
#                         EndNodeId:END_ID(RailwayNode)               :TYPE  \
# 0       railway_node_81.15850001641351.16052680949784  RAILWAY_CONNECTION
# 1   railway_node_-40.83752818595551-5.514524011734167  RAILWAY_CONNECTION
# 2   railway_node_-40.93003264354375-5.502205252584907  RAILWAY_CONNECTION
# 3    railway_node_98.2259611456299814.008849119211256  RAILWAY_CONNECTION
# 4    railway_node_98.2791529794628213.813812394933798  RAILWAY_CONNECTION
# 5    railway_node_98.2835856324512613.769485866131399  RAILWAY_CONNECTION
# 6     railway_node_98.3545080778245513.75175525485712  RAILWAY_CONNECTION
# 7    railway_node_98.3899692996095213.645371587462634  RAILWAY_CONNECTION
# 8     railway_node_98.4431611337160613.56115118434701  RAILWAY_CONNECTION
# 9    railway_node_98.4919203146047313.468065475011727  RAILWAY_CONNECTION
# 10    railway_node_98.545112148347213.366114459936707  RAILWAY_CONNECTION
# 11   railway_node_98.6071692878183213.295192015078314  RAILWAY_CONNECTION
# 12   railway_node_98.6514958160888713.224269569285008  RAILWAY_CONNECTION
# 13   railway_node_98.6426305103986313.073559374471198  RAILWAY_CONNECTION
# 14   railway_node_98.6736590797435712.971608359335743  RAILWAY_CONNECTION
# 15   railway_node_98.6647937748742812.905118566507909  RAILWAY_CONNECTION
# 16   railway_node_98.6869570393551212.838628774152246  RAILWAY_CONNECTION
# 17   railway_node_98.7179856082336512.798734898914958  RAILWAY_CONNECTION
# 18    railway_node_98.7357162194619312.68791857922513  RAILWAY_CONNECTION
# 19    railway_node_98.7268509143551712.59926552178525  RAILWAY_CONNECTION
#
#      distance   impedance
# 0    1.435638    2.061057
# 1    6.664038   44.409404
# 2   10.331537  106.740665
# 3    1.409538    1.986798
# 4    6.679608   44.617161
# 5    0.863713    0.746001
# 6    7.886419   62.195601
# 7    4.300172   18.491483
# 8    6.067605   36.815833
# 9    5.628388   31.678750
# 10   6.144562   37.755643
# 11   6.995538   48.937558
# 12   5.065743   25.661749
# 13   2.703834    7.310716
# 14   3.846790   14.797794
# 15   1.486894    2.210854
# 16   2.703342    7.308058
# 17   3.512690   12.338989
# 18   2.715339    7.373068
# 19   1.790805    3.206981

# %%
for kk in sorted(dfs.keys()):
    print (kk)
    print (dfs[kk].head(5))
# Out:
# cities_nodes_dataframe
#    city_id  em_ed_manufacturing  em_ed_nonmetallic_minerals  \
# 0        0          7435.119696                 5710.450289
# 1        1         12225.143075                  308.723838
# 2        2         16182.671737                 5835.555748
# 3        3         15987.369870                 5323.717696
# 4        4         14045.258506                  354.687512
#
#    em_ed_chemical_processes  em_ed_iron_steel_manufacturing  \
# 0               1207.577099                             0.0
# 1               2015.415935                             0.0
# 2               2649.997738                             0.0
# 3               2619.468710                             0.0
# 4               2315.478330                             0.0
#
#    em_ed_nonferrous_metal_production  em_ed_solvent_products  em_sec_industry  \
# 0                        4216.457203             3654.525399     22224.129686
# 1                           0.000000             2220.106213     16769.389061
# 2                        4143.330319             5265.466931     34077.022473
# 3                        3756.309988             4997.704102     32684.570366
# 4                           0.000000             2545.374377     19260.798726
#
#    en_sec_industry_coal  en_sec_industry_oil  ...  em_ed_shipping  \
# 0          81545.641518        193653.994451  ...     1391.790529
# 1          61530.894941        146123.120325  ...     1184.679909
# 2         125036.736999        296936.330650  ...       46.512058
# 3         119927.497540        284802.946065  ...      960.009741
# 4          70672.472239        167832.471386  ...      422.619505
#
#    em_sec_shipping  en_sec_shipping_coal  en_sec_shipping_oil  \
# 0      1391.790529                   0.0        -2.440781e+08
# 1      1184.679909                   0.0        -2.077572e+08
# 2        46.512058                   0.0        -8.156813e+06
# 3       960.009741                   0.0        -1.683568e+08
# 4       422.619505                   0.0        -7.411473e+07
#
#    en_sec_shipping_gas  total_oil_consumption  total_coal_consumption  \
# 0        -55462.846110           2.463917e+08            82078.311576
# 1        -47209.488860           2.101727e+08            61792.161829
# 2         -1853.505285           1.771241e+07           125902.763385
# 3        -38256.383710           1.745643e+08           120572.203296
# 4        -16841.385307           7.879647e+07            70958.189275
#
#    total_gas_consumption    :LABEL  CityNodeId:ID(CityNode)
# 0           62948.571487  CityNode              city_node_0
# 1           51333.251323  CityNode              city_node_1
# 2           12636.836585  CityNode              city_node_2
# 3           48017.782410  CityNode              city_node_3
# 4           21375.721907  CityNode              city_node_4
#
# [5 rows x 47 columns]
# cities_pipelines_edge_dataframe
#              PipelineNode:START_ID(PipelineNode) CityNode:END_ID(CityNode)  \
# 0  pipe_node_66.9431984117598236.636876537046234               city_node_5
# 1    pipe_node_66.175963969309336.70668579537663               city_node_8
# 2    pipe_node_66.177072120835936.70587708557759              city_node_11
# 3   pipe_node_66.2928751951253237.31693131967456               city_node_8
# 4   pipe_node_66.2964667149132437.32614378950794               city_node_8
#
#                      :TYPE  impedance
# 0  CITY_PIPELINE_CONNECTOR          0
# 1  CITY_PIPELINE_CONNECTOR          0
# 2  CITY_PIPELINE_CONNECTOR          0
# 3  CITY_PIPELINE_CONNECTOR          0
# 4  CITY_PIPELINE_CONNECTOR          0
# cities_ports_edge_dataframe
#   PortNode:START_ID(PortNode) CityNode:END_ID(CityNode)                :TYPE  \
# 0              port_node_1162              city_node_76  CITY_PORT_CONNECTOR
# 1              port_node_1163              city_node_79  CITY_PORT_CONNECTOR
# 2                 port_node_1              city_node_80  CITY_PORT_CONNECTOR
# 3               port_node_995              city_node_80  CITY_PORT_CONNECTOR
# 4              port_node_2545              city_node_80  CITY_PORT_CONNECTOR
#
#    impedance
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# cities_railways_edge_dataframe
#                    RailwayNode:START_ID(RailwayNode)  \
# 0  railway_node_-53.61082305485045-28.64972610078...
# 1  railway_node_-53.61082305485045-28.64972610078...
# 2  railway_node_-53.61082305485045-28.64972610078...
# 3                 railway_node_30.0268274-26.5594987
# 4                 railway_node_22.4728295-33.9634222
#
#   CityNode:END_ID(CityNode)                   :TYPE  impedance
# 0               city_node_5  CITY_RAILWAY_CONNECTOR          0
# 1               city_node_8  CITY_RAILWAY_CONNECTOR          0
# 2              city_node_11  CITY_RAILWAY_CONNECTOR          0
# 3               city_node_8  CITY_RAILWAY_CONNECTOR          0
# 4               city_node_8  CITY_RAILWAY_CONNECTOR          0
# coal_mine_railway_edge_dataframe
#    distance  impedance CoalMineID:START_ID(CoalMine)  \
# 0  4.735738  22.427214                coal_mine_1920
# 1  4.737623  22.445068                coal_mine_1920
# 2  4.748168  22.545096                coal_mine_1920
# 3  4.757613  22.634882                coal_mine_1920
# 4  4.756496  22.624259                coal_mine_1920
#
#     RailwayNodeID:END_ID(RailwayNode)                         :TYPE
# 0  railway_node_25.9222511-24.6199785  COAL_MINE_RAILAWAY_CONNECTOR
# 1     railway_node_25.9217996-24.6199  COAL_MINE_RAILAWAY_CONNECTOR
# 2  railway_node_25.9223869-24.6198721  COAL_MINE_RAILAWAY_CONNECTOR
# 3   railway_node_25.9224935-24.619792  COAL_MINE_RAILAWAY_CONNECTOR
# 4  railway_node_25.9218103-24.6197113  COAL_MINE_RAILAWAY_CONNECTOR
# coal_mines_nodes_dataframe
#   CoalMineID:ID(CoalMine) commodity           facility_n md_country  \
# 0             coal_mine_0      COAL              Unknown     Canada
# 1             coal_mine_1      COAL         CarriesSlope     Canada
# 2             coal_mine_2      COAL      CarriesAirShaft     Canada
# 3             coal_mine_3      COAL              Unknown     Canada
# 4             coal_mine_4      COAL  WilliamPatrickSlope     Canada
#
#                                            md_source  \
# 0  httpsgesnernovascotiacaamosearchsinglereportas...
# 1  httpsgesnernovascotiacaamosearchsinglereportas...
# 2  httpsgesnernovascotiacaamosearchsinglereportas...
# 3  httpsgesnernovascotiacaamosearchsinglereportas...
# 4  httpsgesnernovascotiacaamosearchsinglereportas...
#
#                                 coordinates geometry_type    :LABEL
# 0   [-64.60162215600684, 45.41479345481678]         Point  CoalMine
# 1  [-60.482101515817554, 46.18397905351551]         Point  CoalMine
# 2   [-60.48206782139347, 46.18414931865701]         Point  CoalMine
# 3   [-63.15895481132707, 45.17443047315798]         Point  CoalMine
# 4  [-64.20902914043509, 45.735399448075164]         Point  CoalMine
# lng_nodes_dataframe
#   LngTerminalID:ID(LngTerminal)    commodity                 facility_n  \
# 0                lng_terminal_0  Natural Gas                   Canaport
# 1                lng_terminal_1  Natural Gas                    Unknown
# 2                lng_terminal_2  Natural Gas                    Unknown
# 3                lng_terminal_3  Natural Gas                    Unknown
# 4                lng_terminal_4  Natural Gas  ArzewGNL3ZLNGPlantAlgeria
#
#   md_country  md_fkey                                          md_source  \
# 0     Canada      426  http://www.eia.gov/special/trilat/map/map-reso...
# 1     Mexico      426  http://www.eia.gov/special/trilat/map/map-reso...
# 2     Mexico      426  http://www.eia.gov/special/trilat/map/map-reso...
# 3     Mexico      426  http://www.eia.gov/special/trilat/map/map-reso...
# 4    Algeria      400            http://www.globalenergyobservatory.org/
#
#    md_source0  md_spatial  md_tempora  numbersour onshore_of  \
# 0         5.0         4.7         4.7         1.0   Offshore
# 1         5.0         4.7         4.7         1.0    Onshore
# 2         5.0         4.7         4.7         1.0    Onshore
# 3         5.0         4.7         4.7         1.0   Offshore
# 4         3.7         4.0         3.0         8.0    Onshore
#
#                                             operator     sour_ranks  \
# 0                                             Repsol  5.0; 5.0; 5.0
# 1                          EnagasSAVopakLNGHoldingBV  5.0; 5.0; 5.0
# 2  KoreanGasCorporationKoreaMitsuiCoLtdJaponySams...  5.0; 5.0; 5.0
# 3                          EnergíaCostaAzulSdeRLdeCV  5.0; 5.0; 5.0
# 4                                            Unknown  3.0; 4.0; 4.0
#
#       spat_ranks     temp_ranks                                coordinates  \
# 0  5.0; 4.0; 5.0  5.0; 4.0; 5.0   [-65.97970000034222, 45.210910000116044]
# 1  5.0; 4.0; 5.0  5.0; 4.0; 5.0   [-97.89166669932995, 22.491388899960597]
# 2  5.0; 4.0; 5.0  5.0; 4.0; 5.0  [-104.25777779938542, 19.003333299815296]
# 3  5.0; 4.0; 5.0  5.0; 4.0; 5.0  [-116.84972219938936, 31.990277800081323]
# 4  4.0; 4.0; 4.0  3.0; 3.0; 3.0    [-0.240969999566738, 35.80451999978295]
#
#   geometry_type       :LABEL
# 0         Point  LngTerminal
# 1         Point  LngTerminal
# 2         Point  LngTerminal
# 3         Point  LngTerminal
# 4         Point  LngTerminal
# lng_pipeline_edge_dataframe
#    distance  impedance LngTerminalID:START_ID(LngTerminal)  \
# 0  0.406460   0.165210                      lng_terminal_0
# 1  0.248373   0.061689                     lng_terminal_16
# 2  0.761180   0.579395                    lng_terminal_149
# 3  0.406100   0.164917                      lng_terminal_0
# 4  0.248174   0.061590                     lng_terminal_16
#
#              PipelineNodeID:END_ID(PipelineNode)  \
# 0  pipe_node_-65.9766005109921345.21568078056616
# 1  pipe_node_-65.9766005109921345.21568078056616
# 2  pipe_node_-65.9766005109921345.21568078056616
# 3  pipe_node_-65.9766053135175145.21568458191839
# 4  pipe_node_-65.9766053135175145.21568458191839
#
#                              :TYPE
# 0  LNG_TERMINAL_PIPELINE_CONNECTOR
# 1  LNG_TERMINAL_PIPELINE_CONNECTOR
# 2  LNG_TERMINAL_PIPELINE_CONNECTOR
# 3  LNG_TERMINAL_PIPELINE_CONNECTOR
# 4  LNG_TERMINAL_PIPELINE_CONNECTOR
# lng_shipping_route_edge_dataframe
#   LngTerminal:START_ID(LngTerminal) ShipNode:END_ID(ShippingNode)  \
# 0                    lng_terminal_0           shipping_node_22074
# 1                    lng_terminal_1          shipping_node_201104
# 2                    lng_terminal_2          shipping_node_202273
# 3                    lng_terminal_3          shipping_node_172142
# 4                    lng_terminal_4          shipping_node_133230
#
#                          :TYPE  impedance
# 0  LNG_TERMINAL_SHIP_CONNECTOR          0
# 1  LNG_TERMINAL_SHIP_CONNECTOR          0
# 2  LNG_TERMINAL_SHIP_CONNECTOR          0
# 3  LNG_TERMINAL_SHIP_CONNECTOR          0
# 4  LNG_TERMINAL_SHIP_CONNECTOR          0
# oil_field_edge_dataframe
#     distance    impedance OilFieldID:START_ID(OilField)  \
# 0  88.844708  7893.382132                   oil_field_2
# 1  10.869103   118.137389                  oil_field_16
# 2  91.209747  8319.217959                   oil_field_2
# 3  20.380274   415.355556                  oil_field_16
# 4  65.606927  4304.268864                   oil_field_2
#
#               PipelineNodeID:END_ID(PipelineNode)  \
# 0  pipe_node_-60.2814029999770210.123201000349216
# 1  pipe_node_-60.2814029999770210.123201000349216
# 2  pipe_node_-60.2618019998253710.309404000366206
# 3  pipe_node_-60.2618019998253710.309404000366206
# 4  pipe_node_-60.4994559997190969.968847999700605
#
#                           :TYPE
# 0  OIL_FIELD_PIPELINE_CONNECTOR
# 1  OIL_FIELD_PIPELINE_CONNECTOR
# 2  OIL_FIELD_PIPELINE_CONNECTOR
# 3  OIL_FIELD_PIPELINE_CONNECTOR
# 4  OIL_FIELD_PIPELINE_CONNECTOR
# oil_field_nodes_dataframe
#   OilFieldID:ID(OilField) commodity          facility_n  \
# 0             oil_field_0   Unknown    NorthCrimeaBasin
# 1             oil_field_1   Unknown    NorthCrimeaBasin
# 2             oil_field_2   Unknown  EastVenezuelaBasin
# 3             oil_field_3   Unknown        GuajiraBasin
# 4             oil_field_4   Unknown        GulfofGuinea
#
#                                        md_country  md_fkey  \
# 0                                         Ukraine      407
# 1                                         Ukraine      407
# 2  TrinidadandTobagoVenezuelaBolivarianRepublicof      407
# 3                                        Colombia      407
# 4                                CoteDIvoireGhana      407
#
#                   md_region  \
# 0                    Europe
# 1                    Europe
# 2  NandCAmericaSouthAmerica
# 3              SouthAmerica
# 4                    Africa
#
#                                            md_source  md_source0  md_spatial  \
# 0  httpsworldmapharvardedudatageonodelocation_of_...         5.0         2.0
# 1  httpsworldmapharvardedudatageonodelocation_of_...         5.0         2.0
# 2  httpsworldmapharvardedudatageonodelocation_of_...         5.0         2.0
# 3  httpsworldmapharvardedudatageonodelocation_of_...         5.0         2.0
# 4  httpsworldmapharvardedudatageonodelocation_of_...         5.0         2.0
#
#    md_tempora  ...    shape_area     shape_leng     sour_ranks     spat_ranks  \
# 0         3.0  ...  2.825397e+09  189523.478274  5.0; 5.0; 5.0  2.0; 2.0; 2.0
# 1         3.0  ...  8.424441e+09  360562.407128  5.0; 5.0; 5.0  2.0; 2.0; 2.0
# 2         3.0  ...  1.931163e+10  869799.018362  5.0; 5.0; 5.0  2.0; 2.0; 2.0
# 3         3.0  ...  3.531904e+09  229306.083092  5.0; 5.0; 5.0  2.0; 2.0; 2.0
# 4         3.0  ...  8.983897e+09  645374.035555  5.0; 5.0; 5.0  2.0; 2.0; 2.0
#
#     status     temp_ranks field_type  \
# 0  Unknown  3.0; 3.0; 3.0          2
# 1  Unknown  3.0; 3.0; 3.0          1
# 2  Unknown  3.0; 3.0; 3.0          1
# 3  Unknown  3.0; 3.0; 3.0          1
# 4  Unknown  3.0; 3.0; 3.0          1
#
#                                          coordinates geometry_type    :LABEL
# 0  [[[30.874705166735744, 45.61529619751774], [30...       Polygon  OilField
# 1  [[[31.54499441891102, 45.50967917742115], [31....       Polygon  OilField
# 2  [[[-61.90917205700183, 10.037498470481351], [-...       Polygon  OilField
# 3  [[[-72.58677024375478, 11.754406305182677], [-...       Polygon  OilField
# 4  [[[-4.110169632563522, 5.120581033984478], [-4...       Polygon  OilField
#
# [5 rows x 22 columns]
# pipeline_edge_dataframe
#                 StartNodeId:START_ID(PipelineNode)  \
# 0   pipe_node_115.80294390476467-32.22537359839084
# 1   pipe_node_115.80289695849319-32.22526359703572
# 2  pipe_node_115.95325328017724-21.447117558993117
# 3   pipe_node_118.53732599128922-28.29251017182618
# 4   pipe_node_118.53743598872933-28.29237822633823
#
#                     EndNodeId:END_ID(PipelineNode)                :TYPE  \
# 0   pipe_node_115.80289695849319-32.22526359703572  PIPELINE_CONNECTION
# 1   pipe_node_115.80293306912894-32.22525248574142  PIPELINE_CONNECTION
# 2  pipe_node_115.95357244160904-21.446720608785515  PIPELINE_CONNECTION
# 3   pipe_node_118.53743598872933-28.29237822633823  PIPELINE_CONNECTION
# 4  pipe_node_118.53754487602035-28.292248222770116  PIPELINE_CONNECTION
#
#    distance  impedance
# 0  0.007452   0.000056
# 1  0.004049   0.000016
# 2  0.040380   0.001631
# 3  0.014088   0.000198
# 4  0.013930   0.000194
# pipeline_node_dataframe
#                                  coordinates  \
# 0   (-151.55891900119218, 60.11453500057754)
# 1   (-151.5555570003828, 60.117760999896724)
# 2  (-151.55019700002072, 60.120700000357594)
# 3   (-151.53352899921134, 60.13117499949915)
# 4  (-151.52128900130052, 60.137500000462786)
#
#                        PipeNodeID:ID(PipelineNode)         lat       long  \
# 0   pipe_node_-151.5589190011921860.11453500057754 -151.558919  60.114535
# 1   pipe_node_-151.555557000382860.117760999896724 -151.555557  60.117761
# 2  pipe_node_-151.5501970000207260.120700000357594 -151.550197  60.120700
# 3   pipe_node_-151.5335289992113460.13117499949915 -151.533529  60.131175
# 4  pipe_node_-151.5212890013005260.137500000462786 -151.521289  60.137500
#
#          :LABEL
# 0  PipelineNode
# 1  PipelineNode
# 2  PipelineNode
# 3  PipelineNode
# 4  PipelineNode
# port_node_dataframe
#   PortNodeId:ID(PortNode)        facility_n  md_aquired md_country  md_fkey  \
# 0             port_node_0         ArzewPort  Lucy Romeo    Algeria      400
# 1             port_node_1        SkikdaPort  Lucy Romeo    Algeria      400
# 2             port_node_2       CampanaPort  Lucy Romeo  Argentina      400
# 3             port_node_3     LyttonOilPort  Lucy Romeo  Australia      400
# 4             port_node_4  SchwechatOilPort  Lucy Romeo    Austria      400
#
#                                           md_gaia_lo              md_region  \
# 0  P:\01_DataOriginals\World\EDF\International_Gl...                 Africa
# 1  P:\01_DataOriginals\World\EDF\International_Gl...                 Africa
# 2  P:\01_DataOriginals\World\EDF\International_Gl...          South America
# 3  P:\01_DataOriginals\World\EDF\International_Gl...  Australia and Oceania
# 4  P:\01_DataOriginals\World\EDF\International_Gl...                 Europe
#
#                                  md_source  md_source0  md_spatial  \
# 0  http://www.globalenergyobservatory.org/         3.7         4.0
# 1  http://www.globalenergyobservatory.org/         3.7         4.0
# 2  http://www.globalenergyobservatory.org/         3.7         4.0
# 3  http://www.globalenergyobservatory.org/         3.7         4.0
# 4  http://www.globalenergyobservatory.org/         3.7         4.0
#
#    md_tempora  numbersour onshore_of     sour_ranks     spat_ranks  \
# 0         3.0         8.0   Offshore  3.0; 4.0; 4.0  4.0; 4.0; 4.0
# 1         3.0         8.0   Offshore  3.0; 4.0; 4.0  4.0; 4.0; 4.0
# 2         3.0         8.0    Onshore  3.0; 4.0; 4.0  4.0; 4.0; 4.0
# 3         3.0         8.0    Onshore  3.0; 4.0; 4.0  4.0; 4.0; 4.0
# 4         3.0         8.0    Onshore  3.0; 4.0; 4.0  4.0; 4.0; 4.0
#
#       temp_ranks                                 coordinates    :LABEL
# 0  3.0; 3.0; 3.0     [-0.251507632311896, 35.81756292418291]  PortNode
# 1  3.0; 3.0; 3.0      [6.940713604366562, 36.88478746013768]  PortNode
# 2  3.0; 3.0; 3.0  [-58.951844052210674, -34.154910365976136]  PortNode
# 3  3.0; 3.0; 3.0     [153.1523408378706, -27.40592494346182]  PortNode
# 4  3.0; 3.0; 3.0     [16.51124693781044, 48.168501075721686]  PortNode
# port_pipeline_edge_dataframe
#   PortNode:START_ID(PortNode)             PipelineNodeID:END_ID(PipelineNode)  \
# 0                 port_node_0   pipe_node_-0.23191219313057135.80178293344823
# 1              port_node_1002   pipe_node_-0.23191219313057135.80178293344823
# 2              port_node_1003   pipe_node_-0.23191219313057135.80178293344823
# 3                 port_node_0  pipe_node_-0.269900147157847735.82559627768836
# 4              port_node_1002  pipe_node_-0.269900147157847735.82559627768836
#
#                      :TYPE
# 0  PORT_PIPELINE_CONNECTOR
# 1  PORT_PIPELINE_CONNECTOR
# 2  PORT_PIPELINE_CONNECTOR
# 3  PORT_PIPELINE_CONNECTOR
# 4  PORT_PIPELINE_CONNECTOR
# port_ship_edge_dataframe
#   PortNode:START_ID(PortNode) ShipNode:END_ID(ShippingNode)  \
# 0                 port_node_0          shipping_node_133230
# 1                 port_node_1          shipping_node_122722
# 2                 port_node_2          shipping_node_203210
# 3                 port_node_3          shipping_node_203148
# 4                 port_node_4           shipping_node_23446
#
#                  :TYPE  impedance
# 0  PORT_SHIP_CONNECTOR          0
# 1  PORT_SHIP_CONNECTOR          0
# 2  PORT_SHIP_CONNECTOR          0
# 3  PORT_SHIP_CONNECTOR          0
# 4  PORT_SHIP_CONNECTOR          0
# power_station_nodes_dataframe
#   PowerStationID:ID(PowerStation)  capacity_mw country country_long  fuel1  \
# 0                 power_station_0        33.00     AFG  Afghanistan  Hydro
# 1                 power_station_1        66.00     AFG  Afghanistan  Hydro
# 2                 power_station_2       100.00     AFG  Afghanistan  Hydro
# 3                 power_station_3        11.55     AFG  Afghanistan  Hydro
# 4                 power_station_4        42.00     AFG  Afghanistan    Gas
#
#       gppd_idnr  latitude  longitude  \
# 0  GEODB0040538   32.3220    65.1190
# 1  GEODB0040541   34.5560    69.4787
# 2  GEODB0040534   34.6410    69.7170
# 3  GEODB0040536   34.4847    70.3633
# 4  GEODB0040540   34.5638    69.1134
#
#                                                 name    owner source  \
# 0           KajakiHydroelectricPowerPlantAfghanistan  Unknown  GEODB
# 1          MahiparHydroelectricPowerPlantAfghanistan  Unknown  GEODB
# 2        NaghluDamHydroelectricPowerPlantAfghanistan  Unknown  GEODB
# 3  NangarharDaruntaHydroelectricPowerPlantAfghani...  Unknown  GEODB
# 4                NorthwestKabulPowerPlantAfghanistan  Unknown  GEODB
#
#                                   url         coordinates   type        :LABEL
# 0  http://globalenergyobservatory.org    [65.119, 32.322]  Point  PowerStation
# 1  http://globalenergyobservatory.org   [69.4787, 34.556]  Point  PowerStation
# 2  http://globalenergyobservatory.org    [69.717, 34.641]  Point  PowerStation
# 3  http://globalenergyobservatory.org  [70.3633, 34.4847]  Point  PowerStation
# 4  http://globalenergyobservatory.org  [69.1134, 34.5638]  Point  PowerStation
# power_station_pipeline_edge_dataframe
#    distance  impedance PowerStationID:START_ID(PowerStation)  \
# 0  6.429254  41.335311                      power_station_14
# 1  0.454240   0.206334                      power_station_16
# 2  5.495428  30.199726                      power_station_23
# 3  4.659746  21.713231                      power_station_23
# 4  5.479089  30.020416                      power_station_23
#
#             PipelineNodeID:END_ID(PipelineNode)  \
# 0  pipe_node_19.49000459416882340.4720011293369
# 1  pipe_node_7.76106607760950636.88901313092426
# 2  pipe_node_3.04286747818901936.71901376327928
# 3  pipe_node_3.05021657624101336.72186161522971
# 4  pipe_node_3.03953624383421336.77347690702688
#
#                               :TYPE
# 0  POWER_STATION_PIPELINE_CONNECTOR
# 1  POWER_STATION_PIPELINE_CONNECTOR
# 2  POWER_STATION_PIPELINE_CONNECTOR
# 3  POWER_STATION_PIPELINE_CONNECTOR
# 4  POWER_STATION_PIPELINE_CONNECTOR
# power_station_railway_edge_dataframe
#     distance   impedance PowerStationID:START_ID(PowerStation)  \
# 0  13.335121  177.825449                      power_station_11
# 1   8.650362   74.828757                      power_station_13
# 2   7.583850   57.514786                      power_station_13
# 3   6.551095   42.916842                      power_station_13
# 4   6.380708   40.713429                      power_station_13
#
#    RailwayNodeID:END_ID(RailwayNode)                            :TYPE
# 0     railway_node_19.71050441.68076  POWER_STATION_RAILWAY_CONNECTOR
# 1  railway_node_19.639578241.9311416  POWER_STATION_RAILWAY_CONNECTOR
# 2  railway_node_19.636076241.9412404  POWER_STATION_RAILWAY_CONNECTOR
# 3  railway_node_19.632917241.9511884  POWER_STATION_RAILWAY_CONNECTOR
# 4   railway_node_19.63232641.9528545  POWER_STATION_RAILWAY_CONNECTOR
# processing_plant_nodes_dataframe
#   ProcessingPlantID:ID(ProcessingPlant)            facility_n md_country  \
# 0                    processing_plant_0              Elmworth     Canada
# 1                    processing_plant_1      Encana Resthaven     Canada
# 2                    processing_plant_2              Elmworth     Canada
# 3                    processing_plant_3  Gas Processing Plant     Canada
# 4                    processing_plant_4          Dawson Creek     Canada
#
#    md_fkey          md_region  \
# 0      427  N. and C. America
# 1      427  N. and C. America
# 2      427  N. and C. America
# 3      427  N. and C. America
# 4      427  N. and C. America
#
#                                            md_source  md_source0  md_spatial  \
# 0  http://www.eia.gov/special/trilat/map/map-reso...         5.0         4.7
# 1  http://www.eia.gov/special/trilat/map/map-reso...         5.0         4.7
# 2  http://www.eia.gov/special/trilat/map/map-reso...         5.0         4.7
# 3  http://www.eia.gov/special/trilat/map/map-reso...         5.0         4.7
# 4  http://www.eia.gov/special/trilat/map/map-reso...         5.0         4.7
#
#    md_tempora  numbersour onshore_of  \
# 0         4.7         1.0    Onshore
# 1         4.7         1.0    Onshore
# 2         4.7         1.0    Onshore
# 3         4.7         1.0    Onshore
# 4         4.7         1.0    Onshore
#
#                                             operator     sour_ranks  \
# 0                 ConocoPhillipsCanadaBRCPartnership  5.0; 5.0; 5.0
# 1                              PembinaGasServicesLtd  5.0; 5.0; 5.0
# 2                    CanadianNaturalResourcesLimited  5.0; 5.0; 5.0
# 3                                    ARCResourcesLtd  5.0; 5.0; 5.0
# 4  WestcoastEnergyIncCarryingOnBusinessasSpectraE...  5.0; 5.0; 5.0
#
#       spat_ranks     temp_ranks                                coordinates  \
# 0  5.0; 4.0; 5.0  5.0; 4.0; 5.0  [-119.63317560048371, 55.040847099898926]
# 1  5.0; 4.0; 5.0  5.0; 4.0; 5.0   [-118.33381270002539, 54.17149310016795]
# 2  5.0; 4.0; 5.0  5.0; 4.0; 5.0   [-119.19113079964241, 54.95494889998027]
# 3  5.0; 4.0; 5.0  5.0; 4.0; 5.0   [-117.65016949971172, 54.78601000026275]
# 4  5.0; 4.0; 5.0  5.0; 4.0; 5.0    [-120.5227497996704, 55.79259420002157]
#
#   geometry_type           :LABEL
# 0         Point  ProcessingPlant
# 1         Point  ProcessingPlant
# 2         Point  ProcessingPlant
# 3         Point  ProcessingPlant
# 4         Point  ProcessingPlant
# processing_plant_pipeline_edge_dataframe
#     distance   impedance ProcessingPlantID:START_ID(ProcessingPlant)  \
# 0  15.568098  242.365679                          processing_plant_0
# 1  15.022268  225.668524                        processing_plant_693
# 2   2.777242    7.713074                          processing_plant_0
# 3   2.948255    8.692209                        processing_plant_693
# 4   3.414012   11.655480                          processing_plant_0
#
#                PipelineNodeID:END_ID(PipelineNode)  \
# 0  pipe_node_-119.4941479991134855.075834999753575
# 1  pipe_node_-119.4941479991134855.075834999753575
# 2    pipe_node_-119.6461294495272555.0840644635349
# 3    pipe_node_-119.6461294495272555.0840644635349
# 4   pipe_node_-119.6435840003276955.09929800026675
#
#                                  :TYPE
# 0  PROCESSING_PLANT_PIPELINE_CONNECTOR
# 1  PROCESSING_PLANT_PIPELINE_CONNECTOR
# 2  PROCESSING_PLANT_PIPELINE_CONNECTOR
# 3  PROCESSING_PLANT_PIPELINE_CONNECTOR
# 4  PROCESSING_PLANT_PIPELINE_CONNECTOR
# railway_edge_dataframe
#                    StartNodeId:START_ID(RailwayNode)  \
# 0    railway_node_81.1458067772870851.17616448058104
# 1  railway_node_-40.779270833828264-5.53331712476...
# 2  railway_node_-40.83752818595551-5.514524011734167
# 3   railway_node_98.2259611453085614.097502175406158
# 4   railway_node_98.2259611456299814.008849119211256
#
#                        EndNodeId:END_ID(RailwayNode)               :TYPE  \
# 0      railway_node_81.15850001641351.16052680949784  RAILWAY_CONNECTION
# 1  railway_node_-40.83752818595551-5.514524011734167  RAILWAY_CONNECTION
# 2  railway_node_-40.93003264354375-5.502205252584907  RAILWAY_CONNECTION
# 3   railway_node_98.2259611456299814.008849119211256  RAILWAY_CONNECTION
# 4   railway_node_98.2791529794628213.813812394933798  RAILWAY_CONNECTION
#
#     distance   impedance
# 0   1.435638    2.061057
# 1   6.664038   44.409404
# 2  10.331537  106.740665
# 3   1.409538    1.986798
# 4   6.679608   44.617161
# railway_nodes_dataframe
#                                  coordinates  \
# 0  (-158.15219300029378, 21.387556000051557)
# 1   (-158.15216799970239, 21.38780900006117)
# 2    (-158.15211900047154, 21.3871660001145)
# 3   (-158.15187400009557, 21.38819900025087)
# 4  (-158.15187399963196, 21.386891000336703)
#
#                        RailwayNodeID:ID(RailwayNode)         lat       long  \
# 0  railway_node_-158.1521930002937821.38755600005... -158.152193  21.387556
# 1  railway_node_-158.1521679997023921.38780900006117 -158.152168  21.387809
# 2   railway_node_-158.1521190004715421.3871660001145 -158.152119  21.387166
# 3  railway_node_-158.1518740000955721.38819900025087 -158.151874  21.388199
# 4  railway_node_-158.1518739996319621.38689100033... -158.151874  21.386891
#
#         :LABEL
# 0  RailwayNode
# 1  RailwayNode
# 2  RailwayNode
# 3  RailwayNode
# 4  RailwayNode
# refinery_nodes_dataframe
#   RefineryID:ID(Refinery)                                          Commodity  \
# 0              refinery_0  VirginNaphthaKeroseneGasoilGasolineHeavyfueloi...
# 1              refinery_1                        HeavyFuelOilAsphaltDiluents
# 2              refinery_2               GasolineKeroseneLubeOilNaphtaAsphalt
# 3              refinery_3               GasolineKeroseneLubeOilNaphtaAsphalt
# 4              refinery_4          LPGGasolineNaphtaKeroseneDieselOilFuelBTS
#
#                MD_Aquired_by MD_Country  MD_Fkey  \
# 0  Devin Justman, Lucy Romeo    Albania      424
# 1  Devin Justman, Lucy Romeo    Albania      424
# 2  Devin Justman, Lucy Romeo    Albania      424
# 3  Devin Justman, Lucy Romeo    Albania      424
# 4  Devin Justman, Lucy Romeo    Algeria      424
#
#                                     MD_GAIA_Location MD_Region  \
# 0  P:\01_DataOriginals\World\EDF\International_Gl...    Europe
# 1  P:\01_DataOriginals\World\EDF\International_Gl...    Europe
# 2  P:\01_DataOriginals\World\EDF\International_Gl...    Europe
# 3  P:\01_DataOriginals\World\EDF\International_Gl...    Europe
# 4  P:\01_DataOriginals\World\EDF\International_Gl...    Africa
#
#                                            MD_Source  MD_Source_Data_Quality  \
# 0  http://www.industryabout.com/world-fossil-fuel...                     3.3
# 1  http://www.industryabout.com/world-fossil-fuel...                     3.3
# 2  http://www.industryabout.com/world-fossil-fuel...                     3.3
# 3  http://www.industryabout.com/world-fossil-fuel...                     3.3
# 4  http://www.industryabout.com/world-fossil-fuel...                     3.3
#
#    MD_Source_Date  ...  NumberSources  Onshore_Offshore  \
# 0             NaN  ...            3.0           Onshore
# 1             NaN  ...            3.0           Onshore
# 2             NaN  ...            3.0           Onshore
# 3             NaN  ...            3.0           Onshore
# 4             NaN  ...            3.0           Onshore
#
#                                             Operator     Sour_Ranks  \
# 0   Albanian Refining &amp; Marketing of Oil sh.a...  3.0; 4.0; 3.0
# 1   Albanian Refining &amp; Marketing of Oil sh.a...  3.0; 4.0; 3.0
# 2       Ministry of Economy; Trade and Energy (METE)  3.0; 4.0; 3.0
# 3       Ministry of Economy; Trade and Energy (METE)  3.0; 4.0; 3.0
# 4   Société Nationale pour la Recherche; la Produ...  3.0; 4.0; 3.0
#
#       Spat_Ranks     Temp_Ranks                  Type  \
# 0  5.0; 4.0; 5.0  4.0; 4.0; 4.0          Oil Refinery
# 1  5.0; 4.0; 5.0  4.0; 4.0; 4.0          Oil Refinery
# 2  5.0; 4.0; 5.0  4.0; 4.0; 4.0   Former Oil Refinery
# 3  5.0; 4.0; 5.0  4.0; 4.0; 4.0   Former Oil Refinery
# 4  5.0; 4.0; 5.0  4.0; 4.0; 4.0          Oil Refinery
#
#                                 coordinates   type    :LABEL
# 0  [19.757285000687194, 40.603915999443956]  Point  Refinery
# 1   [19.549792000464766, 40.70752000050792]  Point  Refinery
# 2   [19.969063000094916, 41.03522000002358]  Point  Refinery
# 3   [19.910443999318897, 40.81120600010852]  Point  Refinery
# 4   [3.1206739998474977, 36.67576899995564]  Point  Refinery
#
# [5 rows x 22 columns]
# refinery_pipeline_edge_dataframe
#     distance   impedance RefineryID:START_ID(Refinery)  \
# 0   4.697988   22.071088                    refinery_0
# 1   8.908110   79.354428                    refinery_2
# 2   9.888611   97.784629                    refinery_4
# 3   9.352103   87.461822                    refinery_4
# 4  10.880616  118.387797                    refinery_5
#
#               PipelineNodeID:END_ID(PipelineNode)                        :TYPE
# 0  pipe_node_19.71632255461376840.592804480578096  REFINERY_PIPELINE_CONNECTOR
# 1   pipe_node_20.01953744052535541.10149136082416  REFINERY_PIPELINE_CONNECTOR
# 2    pipe_node_3.04286747818901936.71901376327928  REFINERY_PIPELINE_CONNECTOR
# 3    pipe_node_3.05021657624101336.72186161522971  REFINERY_PIPELINE_CONNECTOR
# 4   pipe_node_-0.23191219313057135.80178293344823  REFINERY_PIPELINE_CONNECTOR
# shipping_edge_dataframe
#   StartNodeId:START_ID(ShippingNode)  Route Freq  impedance       RouteId  \
# 0               shipping_node_203050        22.0     719.60  a625nghd6uql
# 1               shipping_node_201799        10.0     342.40  a625ng7ej3oi
# 2               shipping_node_201799  11135113.0     231.40  a625ng9po8sf
# 3               shipping_node_201266     25037.0      98.44  a625ng9xkqsn
# 4               shipping_node_203108         0.0      13.60  a625nggsov7i
#
#   EndNodeId:END_ID(ShippingNode) RouteName  length  \
# 0           shipping_node_203073       NaN  11.047
# 1           shipping_node_202498       NaN   5.009
# 2           shipping_node_201055       NaN   3.425
# 3           shipping_node_201888       NaN   1.434
# 4           shipping_node_203107       NaN   0.209
#
#                                          coordinates  \
# 0  [[11.0, -19.00001907], [5.516469955, -19.58231...
# 1  [[38.90000916, 20.74999046], [41.20000076, 16....
# 2  [[38.90000916, 20.74999046], [37.0, 23.59999084]]
# 3  [[-71.28975677, 21.54577065], [-72.0, 20.29998...
# 4  [[-175.5, -20.99998093], [-175.296936, -20.951...
#
#                 starting_point                    end_point           :TYPE
# 0         [11.0, -19.00001907]  [5.516469955, -19.58231926]  SHIPPING_ROUTE
# 1   [38.90000916, 20.74999046]    [41.20000076, 16.2999897]  SHIPPING_ROUTE
# 2   [38.90000916, 20.74999046]          [37.0, 23.59999084]  SHIPPING_ROUTE
# 3  [-71.28975677, 21.54577065]          [-72.0, 20.2999897]  SHIPPING_ROUTE
# 4       [-175.5, -20.99998093]  [-175.296936, -20.95126915]  SHIPPING_ROUTE
# shipping_node_dataframe
#   ShippingNodeID:ID(ShippingNode)        :LABEL
# 0             shipping_node_80143  ShippingNode
# 1            shipping_node_199028  ShippingNode
# 2             shipping_node_23823  ShippingNode
# 3            shipping_node_116383  ShippingNode
# 4            shipping_node_203369  ShippingNode
# well_pad_nodes_dataframe
#   WellPadID:ID(WellPad)         facility_n     md_aquired md_country  md_fkey  \
# 0            well_pad_0  UntitledPlacemark  Devin Justman   Cameroon        1
# 1            well_pad_1  UntitledPlacemark  Devin Justman   Cameroon        1
# 2            well_pad_2             NKosso  Devin Justman      Congo        2
# 3            well_pad_3            Bilondo  Devin Justman      Congo        2
# 4            well_pad_4            Azurite  Devin Justman     Angola        2
#
#                                           md_gaia_lo  \
# 0  P:\01_DataOriginals\World\EDF\Africa\OilandGas...
# 1  P:\01_DataOriginals\World\EDF\Africa\OilandGas...
# 2  P:\01_DataOriginals\World\EDF\Africa\OilandGas...
# 3  P:\01_DataOriginals\World\EDF\Africa\OilandGas...
# 4  P:\01_DataOriginals\World\EDF\Africa\OilandGas...
#
#                            md_source  md_source0  md_spatial  md_tempora  \
# 0  admin@oilandgasinfrastructure.com         2.0         2.7         2.3
# 1  admin@oilandgasinfrastructure.com         2.0         2.7         2.3
# 2  admin@oilandgasinfrastructure.com         2.0         2.3         2.3
# 3  admin@oilandgasinfrastructure.com         2.0         2.3         2.3
# 4  admin@oilandgasinfrastructure.com         2.0         2.3         2.3
#
#    numbersour onshore_of operator     sour_ranks     spat_ranks  \
# 0         3.0   Offshore  Unknown  1.0; 3.0; 2.0  3.0; 2.0; 3.0
# 1         3.0   Offshore  Unknown  1.0; 3.0; 2.0  3.0; 2.0; 3.0
# 2         3.0   Offshore  Unknown  1.0; 3.0; 2.0  3.0; 2.0; 2.0
# 3         3.0   Offshore  Unknown  1.0; 3.0; 2.0  3.0; 2.0; 2.0
# 4         3.0   Offshore  Unknown  1.0; 3.0; 2.0  3.0; 2.0; 2.0
#
#       temp_ranks                               coordinates geometry_type  \
# 0  2.0; 2.0; 3.0     [8.56379921438752, 4.260457555062633]         Point
# 1  2.0; 2.0; 3.0     [8.48256895983809, 4.134045965066479]         Point
# 2  2.0; 2.0; 3.0   [11.557773578392334, -5.25424648281541]         Point
# 3  2.0; 2.0; 3.0  [11.432792504769333, -5.348598899306118]         Point
# 4  2.0; 2.0; 3.0  [11.035023625928629, -5.646220560503665]         Point
#
#     :LABEL
# 0  WellPad
# 1  WellPad
# 2  WellPad
# 3  WellPad
# 4  WellPad
# well_pad_pipeline_edge_dataframe
#    distance  impedance WellPadID:START_ID(WellPad)  \
# 0  7.294561  53.210627                  well_pad_0
# 1  6.500287  42.253733                  well_pad_0
# 2  6.552626  42.936912                  well_pad_0
# 3  7.453608  55.556267                  well_pad_0
# 4  9.422266  88.779088                  well_pad_0
#
#             PipelineNodeID:END_ID(PipelineNode)                        :TYPE
# 0  pipe_node_8.6056307914955394.311618235053401  WELL_PAD_PIPELINE_CONNECTOR
# 1   pipe_node_8.541012393804554.314937758890725  WELL_PAD_PIPELINE_CONNECTOR
# 2  pipe_node_8.5406499281668544.315299488629796  WELL_PAD_PIPELINE_CONNECTOR
# 3  pipe_node_8.6010669007084924.316856866736666  WELL_PAD_PIPELINE_CONNECTOR
# 4  pipe_node_8.6228525754709834.321992378753148  WELL_PAD_PIPELINE_CONNECTOR

# %% [markdown]
# ### simplify rail and pipelines in Python

# %%
## pipeline edge df
dfs['oil_field_edge_dataframe'].head(5)

# %% [markdown]
# **Approach**
# - get the node id column names
# - make nx graph from edge df and get nodes of degree==2
# - drop the nodes that are connected to external dfs
# - get connected components, drop isolates
# - merge each component

# %%
df_names = ['port_pipeline_edge_dataframe',
            'cities_pipelines_edge_dataframe',
            'power_station_pipeline_edge_dataframe',
            'lng_pipeline_edge_dataframe',
            'processing_plant_pipeline_edge_dataframe',
            'refinery_pipeline_edge_dataframe',
            'well_pad_pipeline_edge_dataframe',
            'oil_field_edge_dataframe']

# %%
pipeline_node_columns ={}
for df_name in df_names:
    pipeline_node_columns[df_name] = [cc for cc in dfs[df_name].columns if 'PipelineNode' in cc][0]

# %%
keep_connected_nodes = []
for kk,vv in pipeline_node_columns.items():
    keep_connected_nodes += dfs[kk][vv].unique().tolist()

# %%
pickle.dump(keep_connected_nodes,open('./../results_backup/pipeline_connected_nodes.pkl','wb'))

# %%
G = nx.Graph()

# %%
G.add_edges_from([(r[1],r[2],{'distance':r[4]})for r in dfs['pipeline_edge_dataframe'].to_records()])

# %%
degrees = {node:val for (node, val) in G.degree() if val==2}

# %%
list(degrees.keys())[0:4]

# %%
len(degrees)

# %%
len(keep_connected_nodes)

# %%
simplify_nodes = set(degrees.keys()) - set(keep_connected_nodes)

# %%
list(simplify_nodes)

# %%
dfs['pipeline_edge_dataframe'].head(5)

# %%
dfs['pipeline_node_dataframe'].head(5)   #lon, lat are backwards

# %%
for ii_g, g in enumerate(nx.connected_components(G.subgraph(list(simplify_nodes)))):

    subG = G.subgraph(g)
    end_pts = {node:val for (node, val) in subG.degree() if val==1}
    
    drop_nodes = list(g-set(end_pts.keys()))
    #print (end_pts.keys())
    #print (dfs['pipeline_node_dataframe'].loc[list(end_pts.keys()),['lat','long']])
    #new_node = dfs['pipeline_node_dataframe'].loc[list(end_pts.keys()),['lat','long']].mean().to_dict()
    #new_node['PipeNodeID:ID(PipelineNode)']='pipe_node_'+str(new_node['lat'])+str(new_node['lon'])
    #new_node['coordinates'] = (new_node['lat'],new_node['lon'])
    
    new_dist = sum([e[2]['distance'] for e in subG.edges(data=True)])
    new_edge = {
        'StartNodeId:START_ID(PipelineNode)':list(end_pts)[0],
        'EndNodeId:END_ID(PipelineNode)':list(end_pts)[1],
        ':TYPE':'PIPELINE_CONNECTION',
        'distance':new_dist,
        'impedance':new_dist**2,
    }
    
    new_edge = pd.DataFrame.from_dict({kk:[vv] for kk,vv in new_edge.items()}, orient='columns')
    
    
    edge_index = dfs['pipeline_edge_dataframe']['StartNodeId:START_ID(PipelineNode)'].isin(drop_nodes).values \
    + dfs['pipeline_edge_dataframe']['EndNodeId:END_ID(PipelineNode)'].isin(drop_nodes).values
    
    print (f'{ii_g} subgraph len {len(g)}, dropping {np.sum(edge_index)} edges ...')
    #print (dfs['pipeline_edge_dataframe'][edge_index])
    
    dfs['pipeline_edge_dataframe'].drop(index=dfs['pipeline_edge_dataframe'][edge_index].index, inplace=True)
    dfs['pipeline_node_dataframe'].drop(index=drop_nodes, inplace=True)
    dfs['pipeline_edge_dataframe'] = dfs['pipeline_edge_dataframe'].append(new_edge, ignore_index=True)
    
    #input('-->?')

# %%
## preserve connections to ports, cities, powerstations,LNG, processing plants, refineries, wellpads, and fields
print (dfs['port_pipeline_edge_dataframe'].head(5))
print(dfs['cities_pipelines_edge_dataframe'].head(5))
print(dfs['power_station_pipeline_edge_dataframe'].head(5))
print(dfs['lng_pipeline_edge_dataframe'].head(5))
print(dfs['processing_plant_pipeline_edge_dataframe'].head(5))
print(dfs['refinery_pipeline_edge_dataframe'].head(5))
print(dfs['well_pad_pipeline_edge_dataframe'].head(5))
print(dfs['oil_field_edge_dataframe'].head(5))

# %%
dfs['pipeline_node_dataframe'].head(5)

# %%
__author__ = """Loïc Séguin-C. <loicseguin@gmail.com>"""
# Copyright (C) 2010 Loïc Séguin-C. <loicseguin@gmail.com>
# All rights reserved.
# BSD license.

__all__ = ['network_simplex']

from itertools import chain, islice, repeat
from math import ceil, sqrt
import networkx as nx
from networkx.utils import not_implemented_for

try:
    from itertools import izip as zip
except ImportError:
    pass
try:
    range = xrange
except NameError:
    pass


[docs]@not_implemented_for('undirected')
def network_simplex(G, demand='demand', capacity='capacity', weight='weight'):
    r"""Find a minimum cost flow satisfying all demands in digraph G.

    This is a primal network simplex algorithm that uses the leaving
    arc rule to prevent cycling.

    G is a digraph with edge costs and capacities and in which nodes
    have demand, i.e., they want to send or receive some amount of
    flow. A negative demand means that the node wants to send flow, a
    positive demand means that the node want to receive flow. A flow on
    the digraph G satisfies all demand if the net flow into each node
    is equal to the demand of that node.

    Parameters
    ----------
    G : NetworkX graph
        DiGraph on which a minimum cost flow satisfying all demands is
        to be found.

    demand : string
        Nodes of the graph G are expected to have an attribute demand
        that indicates how much flow a node wants to send (negative
        demand) or receive (positive demand). Note that the sum of the
        demands should be 0 otherwise the problem in not feasible. If
        this attribute is not present, a node is considered to have 0
        demand. Default value: 'demand'.

    capacity : string
        Edges of the graph G are expected to have an attribute capacity
        that indicates how much flow the edge can support. If this
        attribute is not present, the edge is considered to have
        infinite capacity. Default value: 'capacity'.

    weight : string
        Edges of the graph G are expected to have an attribute weight
        that indicates the cost incurred by sending one unit of flow on
        that edge. If not present, the weight is considered to be 0.
        Default value: 'weight'.

    Returns
    -------
    flowCost : integer, float
        Cost of a minimum cost flow satisfying all demands.

    flowDict : dictionary
        Dictionary of dictionaries keyed by nodes such that
        flowDict[u][v] is the flow edge (u, v).

    Raises
    ------
    NetworkXError
        This exception is raised if the input graph is not directed,
        not connected or is a multigraph.

    NetworkXUnfeasible
        This exception is raised in the following situations:

            * The sum of the demands is not zero. Then, there is no
              flow satisfying all demands.
            * There is no flow satisfying all demand.

    NetworkXUnbounded
        This exception is raised if the digraph G has a cycle of
        negative cost and infinite capacity. Then, the cost of a flow
        satisfying all demands is unbounded below.

    Notes
    -----
    This algorithm is not guaranteed to work if edge weights or demands
    are floating point numbers (overflows and roundoff errors can
    cause problems). As a workaround you can use integer numbers by
    multiplying the relevant edge attributes by a convenient
    constant factor (eg 100).

    See also
    --------
    cost_of_flow, max_flow_min_cost, min_cost_flow, min_cost_flow_cost

    Examples
    --------
    A simple example of a min cost flow problem.

    >>> import networkx as nx
    >>> G = nx.DiGraph()
    >>> G.add_node('a', demand=-5)
    >>> G.add_node('d', demand=5)
    >>> G.add_edge('a', 'b', weight=3, capacity=4)
    >>> G.add_edge('a', 'c', weight=6, capacity=10)
    >>> G.add_edge('b', 'd', weight=1, capacity=9)
    >>> G.add_edge('c', 'd', weight=2, capacity=5)
    >>> flowCost, flowDict = nx.network_simplex(G)
    >>> flowCost
    24
    >>> flowDict # doctest: +SKIP
    {'a': {'c': 1, 'b': 4}, 'c': {'d': 1}, 'b': {'d': 4}, 'd': {}}

    The mincost flow algorithm can also be used to solve shortest path
    problems. To find the shortest path between two nodes u and v,
    give all edges an infinite capacity, give node u a demand of -1 and
    node v a demand a 1. Then run the network simplex. The value of a
    min cost flow will be the distance between u and v and edges
    carrying positive flow will indicate the path.

    >>> G=nx.DiGraph()
    >>> G.add_weighted_edges_from([('s', 'u' ,10), ('s' ,'x' ,5),
    ...                            ('u', 'v' ,1), ('u' ,'x' ,2),
    ...                            ('v', 'y' ,1), ('x' ,'u' ,3),
    ...                            ('x', 'v' ,5), ('x' ,'y' ,2),
    ...                            ('y', 's' ,7), ('y' ,'v' ,6)])
    >>> G.add_node('s', demand = -1)
    >>> G.add_node('v', demand = 1)
    >>> flowCost, flowDict = nx.network_simplex(G)
    >>> flowCost == nx.shortest_path_length(G, 's', 'v', weight='weight')
    True
    >>> sorted([(u, v) for u in flowDict for v in flowDict[u] if flowDict[u][v] > 0])
    [('s', 'x'), ('u', 'v'), ('x', 'u')]
    >>> nx.shortest_path(G, 's', 'v', weight = 'weight')
    ['s', 'x', 'u', 'v']

    It is possible to change the name of the attributes used for the
    algorithm.

    >>> G = nx.DiGraph()
    >>> G.add_node('p', spam=-4)
    >>> G.add_node('q', spam=2)
    >>> G.add_node('a', spam=-2)
    >>> G.add_node('d', spam=-1)
    >>> G.add_node('t', spam=2)
    >>> G.add_node('w', spam=3)
    >>> G.add_edge('p', 'q', cost=7, vacancies=5)
    >>> G.add_edge('p', 'a', cost=1, vacancies=4)
    >>> G.add_edge('q', 'd', cost=2, vacancies=3)
    >>> G.add_edge('t', 'q', cost=1, vacancies=2)
    >>> G.add_edge('a', 't', cost=2, vacancies=4)
    >>> G.add_edge('d', 'w', cost=3, vacancies=4)
    >>> G.add_edge('t', 'w', cost=4, vacancies=1)
    >>> flowCost, flowDict = nx.network_simplex(G, demand='spam',
    ...                                         capacity='vacancies',
    ...                                         weight='cost')
    >>> flowCost
    37
    >>> flowDict  # doctest: +SKIP
    {'a': {'t': 4}, 'd': {'w': 2}, 'q': {'d': 1}, 'p': {'q': 2, 'a': 2}, 't': {'q': 1, 'w': 1}, 'w': {}}

    References
    ----------
    .. [1] Z. Kiraly, P. Kovacs.
           Efficient implementation of minimum-cost flow algorithms.
           Acta Universitatis Sapientiae, Informatica 4(1):67--118. 2012.
    .. [2] R. Barr, F. Glover, D. Klingman.
           Enhancement of spanning tree labeling procedures for network
           optimization.
           INFOR 17(1):16--34. 1979.
    """
    ###########################################################################
    # Problem essentials extraction and sanity check
    ###########################################################################

    if len(G) == 0:
        raise nx.NetworkXError('graph has no nodes')

    # Number all nodes and edges and hereafter reference them using ONLY their
    # numbers

    N = list(G)                                # nodes
    I = {u: i for i, u in enumerate(N)}        # node indices
    D = [G.nodes[u].get(demand, 0) for u in N]  # node demands

    inf = float('inf')
    for p, b in zip(N, D):
        if abs(b) == inf:
            raise nx.NetworkXError('node %r has infinite demand' % (p,))

    multigraph = G.is_multigraph()
    S = []  # edge sources
    T = []  # edge targets
    if multigraph:
        K = []  # edge keys
    E = {}  # edge indices
    U = []  # edge capacities
    C = []  # edge weights

    if not multigraph:
        edges = G.edges(data=True)
    else:
        edges = G.edges(data=True, keys=True)
    edges = (e for e in edges
             if e[0] != e[1] and e[-1].get(capacity, inf) != 0)
    for i, e in enumerate(edges):
        S.append(I[e[0]])
        T.append(I[e[1]])
        if multigraph:
            K.append(e[2])
        E[e[:-1]] = i
        U.append(e[-1].get(capacity, inf))
        C.append(e[-1].get(weight, 0))

    for e, c in zip(E, C):
        if abs(c) == inf:
            raise nx.NetworkXError('edge %r has infinite weight' % (e,))
    if not multigraph:
        edges = nx.selfloop_edges(G, data=True)
    else:
        edges = nx.selfloop_edges(G, data=True, keys=True)
    for e in edges:
        if abs(e[-1].get(weight, 0)) == inf:
            raise nx.NetworkXError('edge %r has infinite weight' % (e[:-1],))

    ###########################################################################
    # Quick infeasibility detection
    ###########################################################################

    if sum(D) != 0:
        raise nx.NetworkXUnfeasible('total node demand is not zero')
    for e, u in zip(E, U):
        if u < 0:
            raise nx.NetworkXUnfeasible('edge %r has negative capacity' % (e,))
    if not multigraph:
        edges = nx.selfloop_edges(G, data=True)
    else:
        edges = nx.selfloop_edges(G, data=True, keys=True)
    for e in edges:
        if e[-1].get(capacity, inf) < 0:
            raise nx.NetworkXUnfeasible(
                'edge %r has negative capacity' % (e[:-1],))

    ###########################################################################
    # Initialization
    ###########################################################################

    # Add a dummy node -1 and connect all existing nodes to it with infinite-
    # capacity dummy edges. Node -1 will serve as the root of the
    # spanning tree of the network simplex method. The new edges will used to
    # trivially satisfy the node demands and create an initial strongly
    # feasible spanning tree.
    n = len(N)  # number of nodes
    for p, d in enumerate(D):
        if d > 0:  # Must be greater-than here. Zero-demand nodes must have
                   # edges pointing towards the root to ensure strong
                   # feasibility.
            S.append(-1)
            T.append(p)
        else:
            S.append(p)
            T.append(-1)
    faux_inf = 3 * max(chain([sum(u for u in U if u < inf),
                              sum(abs(c) for c in C)],
                             (abs(d) for d in D))) or 1
    C.extend(repeat(faux_inf, n))
    U.extend(repeat(faux_inf, n))

    # Construct the initial spanning tree.
    e = len(E)                                           # number of edges
    x = list(chain(repeat(0, e), (abs(d) for d in D)))   # edge flows
    pi = [faux_inf if d <= 0 else -faux_inf for d in D]  # node potentials
    parent = list(chain(repeat(-1, n), [None]))  # parent nodes
    edge = list(range(e, e + n))                 # edges to parents
    size = list(chain(repeat(1, n), [n + 1]))    # subtree sizes
    next = list(chain(range(1, n), [-1, 0]))     # next nodes in depth-first thread
    prev = list(range(-1, n))                    # previous nodes in depth-first thread
    last = list(chain(range(n), [n - 1]))        # last descendants in depth-first thread

    ###########################################################################
    # Pivot loop
    ###########################################################################

    def reduced_cost(i):
        """Returns the reduced cost of an edge i.
        """
        c = C[i] - pi[S[i]] + pi[T[i]]
        return c if x[i] == 0 else -c

    def find_entering_edges():
        """Yield entering edges until none can be found.
        """
        if e == 0:
            return

        # Entering edges are found by combining Dantzig's rule and Bland's
        # rule. The edges are cyclically grouped into blocks of size B. Within
        # each block, Dantzig's rule is applied to find an entering edge. The
        # blocks to search is determined following Bland's rule.
        B = int(ceil(sqrt(e)))  # pivot block size
        M = (e + B - 1) // B    # number of blocks needed to cover all edges
        m = 0                   # number of consecutive blocks without eligible
        # entering edges
        f = 0                   # first edge in block
        while m < M:
            # Determine the next block of edges.
            l = f + B
            if l <= e:
                edges = range(f, l)
            else:
                l -= e
                edges = chain(range(f, e), range(l))
            f = l
            # Find the first edge with the lowest reduced cost.
            i = min(edges, key=reduced_cost)
            c = reduced_cost(i)
            if c >= 0:
                # No entering edge found in the current block.
                m += 1
            else:
                # Entering edge found.
                if x[i] == 0:
                    p = S[i]
                    q = T[i]
                else:
                    p = T[i]
                    q = S[i]
                yield i, p, q
                m = 0
        # All edges have nonnegative reduced costs. The current flow is
        # optimal.

    def find_apex(p, q):
        """Find the lowest common ancestor of nodes p and q in the spanning
        tree.
        """
        size_p = size[p]
        size_q = size[q]
        while True:
            while size_p < size_q:
                p = parent[p]
                size_p = size[p]
            while size_p > size_q:
                q = parent[q]
                size_q = size[q]
            if size_p == size_q:
                if p != q:
                    p = parent[p]
                    size_p = size[p]
                    q = parent[q]
                    size_q = size[q]
                else:
                    return p

    def trace_path(p, w):
        """Returns the nodes and edges on the path from node p to its ancestor
        w.
        """
        Wn = [p]
        We = []
        while p != w:
            We.append(edge[p])
            p = parent[p]
            Wn.append(p)
        return Wn, We

    def find_cycle(i, p, q):
        """Returns the nodes and edges on the cycle containing edge i == (p, q)
        when the latter is added to the spanning tree.

        The cycle is oriented in the direction from p to q.
        """
        w = find_apex(p, q)
        Wn, We = trace_path(p, w)
        Wn.reverse()
        We.reverse()
        if We != [i]:
            We.append(i)
        WnR, WeR = trace_path(q, w)
        del WnR[-1]
        Wn += WnR
        We += WeR
        return Wn, We

    def residual_capacity(i, p):
        """Returns the residual capacity of an edge i in the direction away
        from its endpoint p.
        """
        return U[i] - x[i] if S[i] == p else x[i]

    def find_leaving_edge(Wn, We):
        """Returns the leaving edge in a cycle represented by Wn and We.
        """
        j, s = min(zip(reversed(We), reversed(Wn)),
                   key=lambda i_p: residual_capacity(*i_p))
        t = T[j] if S[j] == s else S[j]
        return j, s, t

    def augment_flow(Wn, We, f):
        """Augment f units of flow along a cycle represented by Wn and We.
        """
        for i, p in zip(We, Wn):
            if S[i] == p:
                x[i] += f
            else:
                x[i] -= f

    def trace_subtree(p):
        """Yield the nodes in the subtree rooted at a node p.
        """
        yield p
        l = last[p]
        while p != l:
            p = next[p]
            yield p

    def remove_edge(s, t):
        """Remove an edge (s, t) where parent[t] == s from the spanning tree.
        """
        size_t = size[t]
        prev_t = prev[t]
        last_t = last[t]
        next_last_t = next[last_t]
        # Remove (s, t).
        parent[t] = None
        edge[t] = None
        # Remove the subtree rooted at t from the depth-first thread.
        next[prev_t] = next_last_t
        prev[next_last_t] = prev_t
        next[last_t] = t
        prev[t] = last_t
        # Update the subtree sizes and last descendants of the (old) acenstors
        # of t.
        while s is not None:
            size[s] -= size_t
            if last[s] == last_t:
                last[s] = prev_t
            s = parent[s]

    def make_root(q):
        """Make a node q the root of its containing subtree.
        """
        ancestors = []
        while q is not None:
            ancestors.append(q)
            q = parent[q]
        ancestors.reverse()
        for p, q in zip(ancestors, islice(ancestors, 1, None)):
            size_p = size[p]
            last_p = last[p]
            prev_q = prev[q]
            last_q = last[q]
            next_last_q = next[last_q]
            # Make p a child of q.
            parent[p] = q
            parent[q] = None
            edge[p] = edge[q]
            edge[q] = None
            size[p] = size_p - size[q]
            size[q] = size_p
            # Remove the subtree rooted at q from the depth-first thread.
            next[prev_q] = next_last_q
            prev[next_last_q] = prev_q
            next[last_q] = q
            prev[q] = last_q
            if last_p == last_q:
                last[p] = prev_q
                last_p = prev_q
            # Add the remaining parts of the subtree rooted at p as a subtree
            # of q in the depth-first thread.
            prev[p] = last_q
            next[last_q] = p
            next[last_p] = q
            prev[q] = last_p
            last[q] = last_p

    def add_edge(i, p, q):
        """Add an edge (p, q) to the spanning tree where q is the root of a
        subtree.
        """
        last_p = last[p]
        next_last_p = next[last_p]
        size_q = size[q]
        last_q = last[q]
        # Make q a child of p.
        parent[q] = p
        edge[q] = i
        # Insert the subtree rooted at q into the depth-first thread.
        next[last_p] = q
        prev[q] = last_p
        prev[next_last_p] = last_q
        next[last_q] = next_last_p
        # Update the subtree sizes and last descendants of the (new) ancestors
        # of q.
        while p is not None:
            size[p] += size_q
            if last[p] == last_p:
                last[p] = last_q
            p = parent[p]

    def update_potentials(i, p, q):
        """Update the potentials of the nodes in the subtree rooted at a node
        q connected to its parent p by an edge i.
        """
        if q == T[i]:
            d = pi[p] - C[i] - pi[q]
        else:
            d = pi[p] + C[i] - pi[q]
        for q in trace_subtree(q):
            pi[q] += d

    # Pivot loop
    for i, p, q in find_entering_edges():
        Wn, We = find_cycle(i, p, q)
        j, s, t = find_leaving_edge(Wn, We)
        augment_flow(Wn, We, residual_capacity(j, s))
        if i != j:  # Do nothing more if the entering edge is the same as the
                    # the leaving edge.
            if parent[t] != s:
                # Ensure that s is the parent of t.
                s, t = t, s
            if We.index(i) > We.index(j):
                # Ensure that q is in the subtree rooted at t.
                p, q = q, p
            remove_edge(s, t)
            make_root(q)
            add_edge(i, p, q)
            update_potentials(i, p, q)

    ###########################################################################
    # Infeasibility and unboundedness detection
    ###########################################################################

    if any(x[i] != 0 for i in range(-n, 0)):
        raise nx.NetworkXUnfeasible('no flow satisfies all node demands')

    if (any(x[i] * 2 >= faux_inf for i in range(e)) or
        any(e[-1].get(capacity, inf) == inf and e[-1].get(weight, 0) < 0
            for e in nx.selfloop_edges(G, data=True))):
        raise nx.NetworkXUnbounded(
            'negative cycle with infinite capacity found')

    ###########################################################################
    # Flow cost calculation and flow dict construction
    ###########################################################################

    del x[e:]
    flow_cost = sum(c * x for c, x in zip(C, x))
    flow_dict = {n: {} for n in N}

    def add_entry(e):
        """Add a flow dict entry.
        """
        d = flow_dict[e[0]]
        for k in e[1:-2]:
            try:
                d = d[k]
            except KeyError:
                t = {}
                d[k] = t
                d = t
        d[e[-2]] = e[-1]

    S = (N[s] for s in S)  # Use original nodes.
    T = (N[t] for t in T)  # Use original nodes.
    if not multigraph:
        for e in zip(S, T, x):
            add_entry(e)
        edges = G.edges(data=True)
    else:
        for e in zip(S, T, K, x):
            add_entry(e)
        edges = G.edges(data=True, keys=True)
    for e in edges:
        if e[0] != e[1]:
            if e[-1].get(capacity, inf) == 0:
                add_entry(e[:-1] + (0,))
        else:
            c = e[-1].get(weight, 0)
            if c >= 0:
                add_entry(e[:-1] + (0,))
            else:
                u = e[-1][capacity]
                flow_cost += c * u
                add_entry(e[:-1] + (u,))

    return flow_cost, flow_dict
